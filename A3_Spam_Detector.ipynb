# %%
##This block is only for access of files using google drive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

#For accessing any file from google drive, first share it for public access. Copy its id from last part of its address. Then specify the two lines below.
downloaded = drive.CreateFile({'id':"11udsdq6pPymfbAE213Zfry14SgD0QOQl"})   # replace the id with id of file you want to access
downloaded.GetContentFile('spam.csv')        # replace the file name with your file

# %%
#import libraries
import pandas as pd
import numpy as np
import string

#import the data file
filename = 'spam.csv' 

df_sms = pd.read_csv('spam.csv',encoding='latin-1')
df_sms.head()
# Out:
#      v1  ... Unnamed: 4
# 0   ham  ...        NaN
# 1   ham  ...        NaN
# 2  spam  ...        NaN
# 3   ham  ...        NaN
# 4   ham  ...        NaN
#
# [5 rows x 5 columns]

# %%
#Remove the unwanted columns
df_sms = df_sms.drop(["Unnamed: 2", "Unnamed: 3", "Unnamed: 4"], axis=1)
df_sms = df_sms.rename(columns={"v1":"label", "v2":"sms"})
df_sms.head()
# Out:
#   label                                                sms
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
#Print number of records
L = len(df_sms)
print(L)
#Example of accessing a column in pandas dataframe
df_sms.sms
# Out:
# 5572
# 0       Go until jurong point, crazy.. Available only ...
# 1                           Ok lar... Joking wif u oni...
# 2       Free entry in 2 a wkly comp to win FA Cup fina...
# 3       U dun say so early hor... U c already then say...
# 4       Nah I don't think he goes to usf, he lives aro...
#                               ...
# 5567    This is the 2nd time we have tried 2 contact u...
# 5568                Will Ì_ b going to esplanade fr home?
# 5569    Pity, * was in mood for that. So...any other s...
# 5570    The guy did some bitching but I acted like i'd...
# 5571                           Rofl. Its true to its name
# Name: sms, Length: 5572, dtype: object

# %%
#Define a Function to convert sms text to Lower case and remove stop words, punctuation and numbers

def preprocess_Text(input_Text):
  input_Text = input_Text.lower();
  stopwords = ['the','what','is','a','an','of', 'that']
  querywords = input_Text.split()

  resultwords  = [word for word in querywords if word not in stopwords]
  result = ' '.join(resultwords)

  exclude = set(string.punctuation)
  result = ''.join(ch for ch in result if ch not in exclude)

  exclude = set('0123456789')
  result = ''.join(ch for ch in result if ch not in exclude)

  return result;

# %%
#Test the preprocessing funtion
preprocess_Text('Hello, where4 is he.')
# Out:
# 'hello where he'

# %%
#Preprocess all the sms texts
L = len(df_sms)
for i in range(0,L-1):
  df_sms['sms'][i] = preprocess_Text(df_sms['sms'][i])

# %%
#check if preprocessing was applied correctly by looking at any sms
df_sms['sms'][5]
# Out:
# 'freemsg hey there darling its been  weeks now and no word back id like some fun you up for it still tb ok xxx std chgs to send å£ to rcv'

# %%
#Divide the dataframes into training and and testing set
from sklearn.utils import shuffle
df_sms = shuffle(df_sms)
training_Subset = df_sms.iloc[:round(len(df_sms)*0.9),:]   #90% data into training
test_Subset = df_sms.iloc[round(len(df_sms)*0.9):,:]       #10% data into testing
spam_Subset = training_Subset.query('label == "spam"')
ham_Subset = training_Subset.query('label == "ham"');

# %%
training_Subset['sms'][37]
# Out:
# 'i see letter b on my car'

# %%
test_Subset['sms']
# Out:
# 1244                        now im going out  dinner soon
# 4083    quite ok but bit ex u better go eat smth now e...
# 2023    there any movie theatre i can go to and watch ...
# 1599       yeah probably i still gotta check out with leo
# 4557    piss talking someone realise u point this at i...
#                               ...
# 335             tadaaaaa i am home babe are you still up
# 3585    i am hot n horny and willing i live local to y...
# 1229                         jus ans me lar ull noe later
# 3242    pls accept me for one day or am begging you ch...
# 1670                                            lmaonice
# Name: sms, Length: 557, dtype: object

# %%
#combine all text into one large paragraph which shall be used to list unique words
L = len(training_Subset);
all_Text = ""
for i in training_Subset.index:
  all_Text = all_Text + " "+training_Subset['sms'][i];

# %%
all_Text
# Out:
# ' ok both our days so are you making for dinner tonite am i invited mah b ill pick it up tomorrow seems unnecessarily hostile yes just finished watching days our lives i love it urgent call  from your landline your complimentary  ibiza holiday or  cash await collection sae tcs po box  sk wp  ppm  tomorrow i am not going to theatre   so i can come wherever u call me   tell me where and when to come tomorrow wot u up  thout u were gonna call me txt bak luv k kallis ready for bat in nd innings fine do you remember me hmv bonus special  pounds genuine hmv vouchers to be won just answer  easy questions play now send hmv to  more infowwwpercentrealcom got hella gas money want to go on grand nature adventure with galileo in little bit thanks for being there for me just to talk to on saturday you are very dear to me i cherish having you as brother and role model had your mobile  months or more u r entitled to update to latest colour mobiles with camera for free call mobile update co free on  your hamster dead hey so tmr i meet you at pm orchard mrt i love to cuddle i want to hold you in my strong arms right now only  students solved this cat question in xam  ltgt  ltgt  ltgt then  tell me answer if u r brilliantthingi got d answr no nothis kallis home groundamla home town durban nah man my car meant to be crammed full people you call times job today ok umma and ask them to speed up awesome how do i deal with gate charles told me last night but uh yeah urgent we are trying to contact you last weekends draw shows you have won å£ prize guaranteed call  claim code k valid hours only anytime lor chinatown got porridge claypot rice yam cake fishhead beehoon either we eat cheap den go cafe n tok or go nydc or somethin smsservices for yourinclusive text credits pls goto wwwcomuknet login qxj unsubscribe with stop no extra charge help comuk cm ae if i not meeting ì all rite then ill go home lor if ì dun feel like comin its ok spjanuary male sale hot gay chat now cheaper call  national rate from pmin cheap to pmin peak to stop texts call  pmin none thats happening til you get here though  thought i didnt see you freemsg our records indicate you may be entitled to  pounds for accident you had to claim for free reply with yes to this msg to opt out text stop edison has rightly said a fool can ask more questions than wise man can answer now you know why all us are speechless during viva gm and my man carlos definitely coming by mu tonight no excuses have you emigrated or something ok maybe  was bit hopeful you have won nokia i this you get when you win our free auction to take part send nokia to  now hgsuitelands rowwjhl  dont search love let love find u thats why its called falling in love bcoz u dont force yourself u just fall and u know there smeone to hold u bslvyl k give me sec breaking ltgt at cstore beautiful truth against gravity read carefully our heart feels light when someone in it but it feels very heavy when someone leaves it good night thinking u  x all will come alivebetter correct any good looking figure there itself guess who am ithis first time i created web page wwwasjesuscom read all i wrote im waiting for your opinions i want to be your friend   but your not here i cant pick phone right now pls send message wen ur lovable bcums angry wid u dnt take it seriously coz being angry d most childish n true way showing deep affection care n luv kettoda manda have nice day da convey my regards to him then why you not responding armand says get your ass over to epsilon i am in your office na no messageno responcewhat happend hey pple or  for  nightsexcellent location wif breakfast hamper do u reckon as need  arrange transport if u cant do it thanks does she usually take fifteen fucking minutes to respond to yes or no question sleeping nt feeling well no it will reach by  only she telling she will be there i dont know he world famamus sometimes heart remembrs someone very much forgets someone soon bcoz heart will not like everyone but li ...

# %%
#make a table with all unique words
allWords = all_Text.split()

row_Names = [] 
for i in allWords:
      if not i in row_Names:
          row_Names.append(i);
print(row_Names)
# Out:
# ['ok', 'both', 'our', 'days', 'so', 'are', 'you', 'making', 'for', 'dinner', 'tonite', 'am', 'i', 'invited', 'mah', 'b', 'ill', 'pick', 'it', 'up', 'tomorrow', 'seems', 'unnecessarily', 'hostile', 'yes', 'just', 'finished', 'watching', 'lives', 'love', 'urgent', 'call', 'from', 'your', 'landline', 'complimentary', 'ibiza', 'holiday', 'or', 'cash', 'await', 'collection', 'sae', 'tcs', 'po', 'box', 'sk', 'wp', 'ppm', 'not', 'going', 'to', 'theatre', 'can', 'come', 'wherever', 'u', 'me', 'tell', 'where', 'and', 'when', 'wot', 'thout', 'were', 'gonna', 'txt', 'bak', 'luv', 'k', 'kallis', 'ready', 'bat', 'in', 'nd', 'innings', 'fine', 'do', 'remember', 'hmv', 'bonus', 'special', 'pounds', 'genuine', 'vouchers', 'be', 'won', 'answer', 'easy', 'questions', 'play', 'now', 'send', 'more', 'infowwwpercentrealcom', 'got', 'hella', 'gas', 'money', 'want', 'go', 'on', 'grand', 'nature', 'adventure', 'with', 'galileo', 'little', 'bit', 'thanks', 'being', 'there', 'talk', 'saturday', 'very', 'dear', 'cherish', 'having', 'as', 'brother', 'role', 'model', 'had', 'mobile', 'months', 'r', 'entitled', 'update', 'latest', 'colour', 'mobiles', 'camera', 'free', 'co', 'hamster', 'dead', 'hey', 'tmr', 'meet', 'at', 'pm', 'orchard', 'mrt', 'cuddle', 'hold', 'my', 'strong', 'arms', 'right', 'only', 'students', 'solved', 'this', 'cat', 'question', 'xam', 'ltgt', 'then', 'if', 'brilliantthingi', 'd', 'answr', 'no', 'nothis', 'home', 'groundamla', 'town', 'durban', 'nah', 'man', 'car', 'meant', 'crammed', 'full', 'people', 'times', 'job', 'today', 'umma', 'ask', 'them', 'speed', 'awesome', 'how', 'deal', 'gate', 'charles', 'told', 'last', 'night', 'but', 'uh', 'yeah', 'we', 'trying', 'contact', 'weekends', 'draw', 'shows', 'have', 'å£', 'prize', 'guaranteed', 'claim', 'code', 'valid', 'hours', 'anytime', 'lor', 'chinatown', 'porridge', 'claypot', 'rice', 'yam', 'cake', 'fishhead', 'beehoon', 'either', 'eat', 'cheap', 'den', 'cafe', 'n', 'tok', 'nydc', 'somethin', 'smsservices', 'yourinclusive', 'text', 'credits', 'pls', 'goto', 'wwwcomuknet', 'login', 'qxj', 'unsubscribe', 'stop', 'extra', 'charge', 'help', 'comuk', 'cm', 'ae', 'meeting', 'ì', 'all', 'rite', 'dun', 'feel', 'like', 'comin', 'its', 'spjanuary', 'male', 'sale', 'hot', 'gay', 'chat', 'cheaper', 'national', 'rate', 'pmin', 'peak', 'texts', 'none', 'thats', 'happening', 'til', 'get', 'here', 'though', 'thought', 'didnt', 'see', 'freemsg', 'records', 'indicate', 'may', 'accident', 'reply', 'msg', 'opt', 'out', 'edison', 'has', 'rightly', 'said', 'a', 'fool', 'than', 'wise', 'know', 'why', 'us', 'speechless', 'during', 'viva', 'gm', 'carlos', 'definitely', 'coming', 'by', 'mu', 'tonight', 'excuses', 'emigrated', 'something', 'maybe', 'was', 'hopeful', 'nokia', 'win', 'auction', 'take', 'part', 'hgsuitelands', 'rowwjhl', 'dont', 'search', 'let', 'find', 'called', 'falling', 'bcoz', 'force', 'yourself', 'fall', 'smeone', 'bslvyl', 'give', 'sec', 'breaking', 'cstore', 'beautiful', 'truth', 'against', 'gravity', 'read', 'carefully', 'heart', 'feels', 'light', 'someone', 'heavy', 'leaves', 'good', 'thinking', 'x', 'will', 'alivebetter', 'correct', 'any', 'looking', 'figure', 'itself', 'guess', 'who', 'ithis', 'first', 'time', 'created', 'web', 'page', 'wwwasjesuscom', 'wrote', 'im', 'waiting', 'opinions', 'friend', 'cant', 'phone', 'message', 'wen', 'ur', 'lovable', 'bcums', 'angry', 'wid', 'dnt', 'seriously', 'coz', 'most', 'childish', 'true', 'way', 'showing', 'deep', 'affection', 'care', 'kettoda', 'manda', 'nice', 'day', 'da', 'convey', 'regards', 'him', 'responding', 'armand', 'says', 'ass', 'over', 'epsilon', 'office', 'na', 'messageno', 'responcewhat', 'happend', 'pple', 'nightsexcellent', 'location', 'wif', 'breakfast', 'hamper', 'reckon', 'need', 'arrange', 'transport', 'does', 'she', 'usually', 'fifteen', 'fucking', 'minutes', 'respond', 'sleeping', 'nt', 'feeling', 'well', 'reach', 'telling', 'he', 'world', 'famamus', 'sometimes', 'remembrs', 'much', 'forgets', 'soon', 'everyone', 'liked',  ...

# %%
#For each word find inspam probability and in-ham probability
word = '';
inSpamCount = 0;
inHamCount = 0;
columns = ['inSpamProbability','inHamProbability']
probability_Table = pd.DataFrame(index=row_Names, columns=columns)
for word in row_Names:
  inSpamCount = 0;
  inHamCount = 0;
  for i in spam_Subset['sms']:
    if(i.find(word)==0):
      inSpamCount = inSpamCount+1;
  for i in ham_Subset['sms']:
    if(i.find(word)==0):
      inHamCount = inHamCount+1;
  probability_Table.at[word, 'inSpamProbability'] = inSpamCount/len(spam_Subset);
  probability_Table.at[word,'inHamProbability'] = inHamCount/len(ham_Subset);

# %%
probability_Table.sort_values("inSpamProbability", axis = 0, ascending = False, 
                 inplace = True, na_position ='first')

# %%
probability_Table
# Out:
#                inSpamProbability inHamProbability
# u                       0.127407         0.018894
# f                       0.100741        0.0140553
# y                      0.0962963        0.0695853
# ur                     0.0933333       0.00115207
# you                    0.0933333        0.0232719
# ...                          ...              ...
# iam                            0                0
# jamstercouk                    0                0
# logosmusicnews                 0                0
# videosounds                    0                0
# sherawat                       0                0
#
# [8099 rows x 2 columns]

# %%
#drop rows wherever spam or ham is zero probability
probability_Table = probability_Table[(probability_Table[['inSpamProbability','inHamProbability']] != 0).all(axis=1)]

# %% [markdown]
# #Assignment
#
# 1. Write a code to determine if a msg is spam or ham (2)
#                def check_msg(test_Msg):
#                 ............
#                 ..........
# 2. Write a code to test all messages in test data and determine the following percentages (1)
#   * True positive rate
#   * True negative rate
#   * False positive rate
#   * False negative rate
#   * Accuracy
#   * Error_Rate

# %%
#function to detect spam or ham sms using naive bayes
def check_msg(test_msg):
  spamProb=1
  hamProb=1
  for i in test_msg:
    for j in range(len(probability_Table)):
      if i==probability_Table.index[j]:
        spamProb=spamProb*probability_Table.inSpamProbability[j] 
        hamProb=hamProb*probability_Table.inHamProbability[j]
  if spamProb >=hamProb:
    return 'spam'
  else:
    return 'ham'

# %%
test_Subset=test_Subset.reset_index(drop=True) #reseting the index of the test subset
test_Subset # with sorted index numbering
# Out:
#     label                                                sms
# 0     ham                      now im going out  dinner soon
# 1     ham  quite ok but bit ex u better go eat smth now e...
# 2     ham  there any movie theatre i can go to and watch ...
# 3     ham     yeah probably i still gotta check out with leo
# 4     ham  piss talking someone realise u point this at i...
# ..    ...                                                ...
# 552   ham          tadaaaaa i am home babe are you still up
# 553  spam  i am hot n horny and willing i live local to y...
# 554   ham                       jus ans me lar ull noe later
# 555   ham  pls accept me for one day or am begging you ch...
# 556   ham                                          lmaonice
#
# [557 rows x 2 columns]

# %%
#checking if sms is spam or ham
check_msg(test_Subset['sms'][3])
# Out:
# 'ham'

# %%
#Calculation of True positive rate,True negative rate,False positive rate,False negative rate,Accuracy,Error_Rate

ac=0;
tp=0
tn=0
fp=0
fn=0

for i in range(len(test_Subset)):
  if check_msg(test_Subset['sms'][i])==test_Subset['label'][i]:
    ac=ac+1;
  if test_Subset['label'][i]=='ham' and check_msg(test_Subset['sms'][i])=='ham': #condition for true positive
    tp=tp+1;
  if test_Subset['label'][i]=='ham' and check_msg(test_Subset['sms'][i])=='spam': #condition for false negative
    fn=fn+1; 
  if test_Subset['label'][i]=='spam' and check_msg(test_Subset['sms'][i])=='ham': #condition for false positive
    fp=fp+1;
  if test_Subset['label'][i]=='spam' and check_msg(test_Subset['sms'][i])=='spam': #condition for true negative
    tn=tn+1;
accuracy=ac/len(test_Subset)*100
truePositive=tp/len(test_Subset)*100
falseNegative=fn/len(test_Subset)*100
falsePositive=fp/len(test_Subset)*100
trueNegative=tn/len(test_Subset)*100
print ("Accuracy: ", accuracy,'%')
print ("True Positive: ",truePositive)
print ("True Negative: ",trueNegative)
print ("False Positive: ",falsePositive)
print ("False Negative: ",falseNegative)
print ("Error Rate: ",100-accuracy)
# Out:
# Accuracy:  84.56014362657092 %
# True Positive:  84.38061041292639
# True Negative:  0.17953321364452424
# False Positive:  12.746858168761221
# False Negative:  2.6929982046678633
# Error Rate:  15.43985637342908
